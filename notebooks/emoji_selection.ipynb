# %% [markdown]
# # Emoji Selection

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import emoji
import pandas as pd
import numpy as np
import warnings
import pickle as pk
import numpy as np
from src.utils import print_mem_usage, tononymize,genderonymize,genderonymize_list
from src.data.common_emojis import load_or_compute_emdf
from src.constants import skin_tones, flags, em_letters,EMOJIS,FE0F_DICT,man_woman,em_numbers
from src.utils import extract_emojis,group_fe0f_dic,group_tone_dic,print_em_set,keep_fe0f_emojis, detect_hold_hands,tononymize_list
from numpy.random import permutation
warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format='retina'

# %%
#print_em_set(emoji.UNICODE_EMOJI.keys())

# %%
emojis = set(emoji.UNICODE_EMOJI.keys())
print(f"Original length:{len(emojis)}")
# Out:
# Original length:3859

# %%
emojis = [em for em in emojis if em not in (flags +em_letters+em_numbers)]
print(f"Removing flags and letters and numbers:{len(emojis)}")

emojis = tononymize_list(emojis)
print(f"Removing tones:{len(emojis)}")

emojis = genderonymize_list(emojis)
print(f"Removing gender:{len(emojis)}")

emojis = sorted(keep_fe0f_emojis(emojis))
print(f"Removing fe0f equivalent:{len(emojis)}")
# Out:
# Removing flags and letters and numbers:1349
# Removing tones:1349
# Removing gender:1349
# Removing fe0f equivalent:1349

# %%
print_em_set(emojis)
# Out:
# #️⃣*️⃣©️®️‼️⁉️™️ℹ️↔️↕️↖️↗️↘️↙️↩️↪️⌚⌛⌨️⏏️⏩⏪⏫⏬⏭️⏮️⏯️⏰⏱️⏲️⏳⏸️⏹️⏺️Ⓜ️▪️▫️▶️◀️◻️◼️◽◾☀️☁️☂️☃️☄️☎️☑️☔☕☘️☝️☠️☢️☣️☦️☪️☮️☯️☸️☹️☺️♈♉♊♋♌♍♎♏♐♑♒♓♟️♠️♣️♥️♦️♨️♻️♾️♿⚒️⚓⚔️⚕️⚖️⚗️⚙️⚛️⚜️⚠️⚡⚪⚫⚰️⚱️⚽⚾⛄⛅⛈️⛎⛏️⛑️⛓️⛔⛩️⛪⛰️⛱️⛲⛳⛴️⛵⛷️⛸️⛹️⛺⛽✂️✅✈️✉️✊✋✌️✍️✏️✒️✔️✖️✝️✡️✨✳️✴️❄️❇️❌❎❓❔❕❗❣️❤️➕➖➗➡️➰➿⤴️⤵️⬅️⬆️⬇️⬛⬜⭐⭕〰️〽️㊗️㊙️🀄🃏🅰️🅱️🅾️🅿️🆎🆑🆒🆓🆔🆕🆖🆗🆘🆙🆚🈁🈂️🈚🈯🈲🈳🈴🈵🈶🈷️🈸🈹🈺🉐🉑🌀🌁🌂🌃🌄🌅🌆🌇🌈🌉🌊🌋🌌🌍🌎🌏🌐🌑🌒🌓🌔🌕🌖🌗🌘🌙🌚🌛🌜🌝🌞🌟🌠🌡️🌤️🌥️🌦️🌧️🌨️🌩️🌪️🌫️🌬️🌭🌮🌯🌰🌱🌲🌳🌴🌵🌶️🌷🌸🌹🌺🌻🌼🌽🌾🌿🍀🍁🍂🍃🍄🍅🍆🍇🍈🍉🍊🍋🍌🍍🍎🍏🍐🍑🍒🍓🍔🍕🍖🍗🍘🍙🍚🍛🍜🍝🍞🍟🍠🍡🍢🍣🍤🍥🍦🍧🍨🍩🍪🍫🍬🍭🍮🍯🍰🍱🍲🍳🍴🍵🍶🍷🍸🍹🍺🍻🍼🍽️🍾🍿🎀🎁🎂🎃🎄🎅🎆🎇🎈🎉🎊🎋🎍🎎🎏🎐🎑🎒🎓🎖️🎗️🎙️🎚️🎛️🎞️🎟️🎠🎡🎢🎣🎤🎥🎦🎧🎨🎩🎪🎫🎬🎭🎮🎯🎰🎱🎲🎳🎴🎵🎶🎷🎸🎹🎺🎻🎼🎽🎾🎿🏀🏂🏃🏄🏅🏆🏇🏈🏉🏊🏋️🏌️🏍️🏎️🏏🏐🏑🏒🏓🏔️🏕️🏖️🏗️🏘️🏙️🏚️🏛️🏜️🏝️🏞️🏟️🏠🏡🏢🏣🏤🏥🏦🏧🏨🏩🏪🏫🏬🏭🏮🏯🏰🏳️🏳️‍🌈🏴‍☠️🏴󠁧󠁢󠁥󠁮󠁧󠁿🏴󠁧󠁢󠁳󠁣󠁴󠁿🏴󠁧󠁢󠁷󠁬󠁳󠁿🏵️🏷️🏸🏹🏺🐀🐁🐂🐃🐄🐅🐆🐇🐈🐉🐊🐋🐌🐍🐎🐏🐐🐑🐒🐓🐔🐕🐕‍🦺🐖🐗🐘🐙🐚🐛🐜🐝🐞🐟🐠🐡🐢🐣🐤🐥🐦🐧🐨🐩🐪🐫🐬🐭🐮🐯🐰🐱🐲🐳🐴🐵🐶🐷🐸🐹🐺🐻🐼🐽🐾🐿️👀👁️👁️‍🗨👂👃👄👅👆👇👈👉👊👋👌👍👎👏👐👑👒👓👔👕👖👗👘👙👚👛👜👝👞👟👠👡👢👣👤👥👦👧👨👨‍⚕️👨‍⚖️👨‍✈️👨‍❤️‍👨👨‍❤️‍💋‍👨👨‍🌾👨‍🍳👨‍🎓👨‍🎤👨‍🎨👨‍🏫👨‍🏭👨‍👦👨‍👦‍👦👨‍👧👨‍👧‍👦👨‍👧‍👧👨‍👨‍👦👨‍👨‍👦‍👦👨‍👨‍👧👨‍👨‍👧‍👦👨‍👨‍👧‍👧👨‍👩‍👦👨‍👩‍👦‍👦👨‍👩‍👧👨‍👩‍👧‍👦👨‍👩‍👧‍👧👨‍💻👨‍💼👨‍🔧👨‍🔬👨‍🚀👨‍🚒👨‍🦯👨‍🦰👨‍🦱👨‍🦲👨‍🦳👨‍🦼👨‍🦽👩👩‍⚕️👩‍⚖️👩‍✈️👩‍❤️‍👨👩‍❤️‍👩👩‍❤️‍💋‍👨👩‍❤️‍💋‍👩👩‍🌾👩‍🍳👩‍🎓👩‍🎤👩�
�🛶🛷🛸🛹🛺🟠🟡🟢🟣🟤🟥🟦🟧🟨🟩🟪🟫🤍🤎🤏🤐🤑🤒🤓🤔🤕🤖🤗🤘🤙🤚🤛🤜🤝🤞🤟🤠🤡🤢🤣🤤🤥🤦🤧🤨🤩🤪🤫🤬🤭🤮🤯🤰🤱🤲🤳🤴🤵🤶🤷🤸🤹🤺🤼🤽🤾🤿🥀🥁🥂🥃🥄🥅🥇🥈🥉🥊🥋🥌🥍🥎🥏🥐🥑🥒🥓🥔🥕🥖🥗🥘🥙🥚🥛🥜🥝🥞🥟🥠🥡🥢🥣🥤🥥🥦🥧🥨🥩🥪🥫🥬🥭🥮🥯🥰🥱🥳🥴🥵🥶🥺🥻🥼🥽🥾🥿🦀🦁🦂🦃🦄🦅🦆🦇🦈🦉🦊🦋🦌🦍🦎🦏🦐🦑🦒🦓🦔🦕🦖🦗🦘🦙🦚🦛🦜🦝🦞🦟🦠🦡🦢🦥🦦🦧🦨🦩🦪🦮🦯🦰🦱🦲🦳🦴🦵🦶🦷🦸🦹🦺🦻🦼🦽🦾🦿🧀🧁🧂🧃🧄🧅🧆🧇🧈🧉🧊🧍🧎🧏🧐🧑🧑‍🤝‍🧑🧒🧓🧔🧕🧖🧗🧘🧙🧚🧛🧜🧝🧞🧟🧠🧡🧢🧣🧤🧥🧦🧧🧨🧩🧪🧫🧬🧭🧮🧯🧰🧱🧲🧳🧴🧵🧶🧷🧸🧹🧺🧻🧼🧽🧾🧿🩰🩱🩲🩳🩸🩹🩺🪀🪁🪂🪐🪑🪒🪓🪔🪕

# %%
em2idx = pk.load(open("../data/processed/emojis_png/all/dic.pk","rb"))
idx2em = {value:key for key,value in em2idx.items()}

# %%
selected_emojis_idxes = [em2idx[em] for em in emojis]
print("[",end="")
for idx in np.random.permutation(selected_emojis_idxes):
    print(f"{idx},",end="")
# Out:
# [1159,3847,1047,433,2428,885,2995,2256,2991,1364,1192,437,2500,2249,2285,2516,1189,737,1261,2280,2270,3852,3809,1298,1134,1070,602,3067,428,1301,846,1167,2553,2185,736,588,1450,2710,863,2883,2963,161,2095,1118,718,2568,2762,1130,743,903,1121,2647,1193,3018,814,2112,2941,2896,584,1061,871,2779,3048,630,999,1077,2982,2778,2845,3316,1283,179,839,1168,682,2899,2843,2624,2705,2145,2575,2255,2108,2867,273,3076,2979,1356,726,485,229,565,2901,1291,1175,1025,2850,972,1287,2724,873,845,1206,958,2264,600,1318,1260,1300,828,2917,274,2533,2446,980,1065,538,3837,2948,875,3001,3811,2904,653,1257,1237,3055,2785,2839,2936,1273,2224,887,251,663,553,1197,1195,2171,914,2152,163,1294,2287,1736,2772,375,474,2969,2124,2494,984,892,740,2687,591,2130,1494,2877,240,142,739,388,2027,2712,1327,2955,1076,1239,1647,3000,746,367,3
,1236,537,1518,2848,820,776,1049,1137,519,1140,3097,910,2949,3101,2775,2730,3057,943,1188,2789,3559,2678,153,702,928,3836,2898,3085,908,1133,990,2922,654,359,821,2640,976,404,530,2190,363,2749,2929,572,2930,2890,1037,378,384,2638,3005,516,672,266,1098,945,2773,2,2812,1955,1079,566,1082,581,3542,2600,558,3090,2279,2562,2166,1060,3846,2134,2810,529,685,50,2143,2945,1128,58,2391,2646,1020,2984,605,2716,2708,2118,2561,815,1,3084,2873,1666,2139,236,3,6,975,3310,1202,376,559,2033,2838,848,2800,3016,2113,1317,2026,3071,2759,2244,2385,438,2421,800,931,1512,522,723,3855,973,3858,2791,2348,456,2692,822,2341,2030,1129,2631,2170,983,3038,263,2836,2119,3083,2475,2161,2515,343,965,108,523,2747,451,2123,2282,459 ...

# %% [markdown]
# # Twitter Value counts

# %%
em_df = load_or_compute_emdf(em_path="../data/raw/tweets/em_counts.csv")
em_df = em_df.to_dict()
em_df = pd.Series(group_fe0f_dic(group_tone_dic(em_df))).sort_values(ascending=False)

# %%
tweet_set = set(em_df.index)
emojis_set = set(emojis)

inter = tweet_set.intersection(emojis_set)
missing_set = tweet_set - emojis_set
print(f"Covered percentage:{len(inter)/len(tweet_set) * 100:.2f}")
print("Missing emojis:")
print_em_set(missing_set)
# Out:
# Covered percentage:91.05
# Missing emojis:
# 🚵‍♀️🇶🧘‍♀️🧜‍♂️🙆‍♂️🤦‍♂️🤹‍♂️👷‍♀️🚣‍♀️🇱🏃‍♀️👷‍♂️⛹️‍♀🙎‍♂️🤸‍♂️🏃‍♂️🤼‍♀️🧟‍♀️🕵️‍♂🇦👳‍♂️🚴‍♀️👯‍♀️🇨🇰🏁💁‍♀️🙅‍♀️🇭🎌🇪🏊‍♂️🇹🙇‍♂️🚶‍♀️🤸‍♀️🙋‍♂️🧛‍♂️🚩🏊‍♀️🧖‍♀️🇴🤾‍♀️🧞‍♂️🇼🇿🇧🙅‍♂️🇵🧖‍♂️🇲🧞‍♀️🙆‍♀️⛹️‍♂🤷‍♀️🧚‍♂️🇮🦸‍♂️👮‍♀️🏌️‍♂🚣‍♂️🇩🇺🇳🚶‍♂️🚴‍♂️🏄‍♂️🙇‍♀️🤷‍♂️🏋️‍♂🙍‍♀️🇯♂️💁‍♂️🧜‍♀️🏄‍♀️🤽‍♂️🏌️‍♀🧙‍♂️🏴👯‍♂️🏋️‍♀🙎‍♀️🦸‍♀️♀️🧘‍♂️🙋‍♀️🇻🤾‍♂️👱‍♂️🇽🤦‍♀️🧙‍♀️💂‍♀️💆‍♂️🙍‍♂️💇‍♀️💇‍♂️🧚‍♀️🦹‍♀️🇾👮‍♂️🧟‍♂️🇬🇫🚵‍♂️👱‍♀️💆‍♀️🤼‍♂️🇸🕵️‍♀🤹‍♀️🇷
