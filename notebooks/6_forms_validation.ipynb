# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.constants import GMAP_DRIVE_ID, CREDS_PATH, QUALITY_CHECK_DIR
from src.collect.forms_validation import quality_check
from mt2gf.gform import get_drive_service, get_gform_map, download_multi_csv
from pathlib import Path

# %% [markdown]
# # Preprocessing

# %% [markdown]
# <div class="alert alert-success">
# Preprocessing of data gathered from mturk/gform: quality checks of the forms etc
# </div>

# %%
# Retrieve the urls of the forms generated by the app script
service = get_drive_service(CREDS_PATH)
gform_map = get_gform_map(service, GMAP_DRIVE_ID, "/dev/null")

if not any(list(QUALITY_CHECK_DIR.glob("*.csv"))):
    download_multi_csv(gform_map, QUALITY_CHECK_DIR, service)

quality_check(QUALITY_CHECK_DIR)
# Out:
# Download 100%
# Forms in right format:
# **All emojis are present
# **Honeypots well placed
