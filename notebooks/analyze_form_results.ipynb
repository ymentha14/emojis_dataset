# %%
from src.data.fraudulous import detect_honey_frauders
from src.constants import HONEYPOTS, LOG_FORMS_RESULTS_DIR
import pandas as pd
import Levenshtein
from pathlib import Path

# %%
def get_em2vocab(path):
    em2vocab = {}
    for path in path.glob("**/*.csv"):
        df = pd.read_csv(path)
        emojis = [col for col in df.columns if col not in ["Timestamp", "Worker ID","Feedback"]]
        for em in emojis:
            vocab = em2vocab.get(em,{})
            for word,count in df[em].value_counts().iteritems():
                pre_count = vocab.get(word,0)
                pre_count += count
                vocab[word] = pre_count
            em2vocab[em] = vocab
    return em2vocab

# %%
em2vocab = get_em2vocab(Path("../data/processed/auto_mturk/forms_log_results/run4/"))

# %%
def write_em2vocab(em2vocab,path):
    with open(path,"w") as f:
        for em,wordcounts in em2vocab.items():
            f.write(em+ "\n")
            # sort by count value
            wordcounts = {k: v for k, v in sorted(wordcounts.items(), key=lambda item: item[1],reverse=True)}
            for word,count in wordcounts.items():
                f.write(f"\t{word}:{count}\n")

# %%
write_em2vocab(em2vocab,"./emvoc_500ass.txt")

# %%
# vocabulary mapping a vocabulary to each emoji
voc = {}

# %%
LOG_FORMS_RESULTS_DIR.iterdir

# %%
def display_whole_dir(directory):
    for path in directory.glob("*.csv"):
        df = pd.read_csv(path)
        display(df)

# %%
display_whole_dir(Path("../data/processed/auto_mturk/forms_log_results/run3/"))
# Out:
#              Timestamp       Worker ID        🔈       🥜         😆        📭  \
# 0  02/12/2020 12:05:24   ACY3ZOOZMVS7Y  speaker  peanut  laughter  mailbox
# 1  02/12/2020 12:07:41  A18LAR2IV3FHF9   volume    nuts     smile     mail
# 2  02/12/2020 12:08:27  A1CY01G7686ORZ  speaker  peanut    cheeky  mailbox
# 3  02/12/2020 12:10:26   AFIK3VBMMX6G6  speaker  peanut  laughing  mailbox
# 4  02/12/2020 12:21:51  A3633T8CM8SXW8  speaker  peanut     laugh  mailbox
# 5  02/12/2020 12:21:52   ACJFWPKW4JA59  speaker     nut     happy     mail
# 6  02/12/2020 12:23:57   AS4NIEQJWCG3M  speaker  peanut  laughing  mailbox
# 7  02/12/2020 12:24:47  A34STBV3ZX0Z5T  speaker     nut     happy     sent
# 8  02/12/2020 12:26:59  A1XHK92L7Q7VEU  speaker  peanut  laughing  mailbox
# 9  02/12/2020 12:36:18   AP05055ECEO89  speaker    seed     smile     pipe
#
#          🎞️        ☂️      💣             🛐       🌸        🛣️          📡  \
# 0     movie  umbrella   bomb       praying  flower   driving      alarm
# 1     video  umbrella   bomb        prayer  flower     trail    speaker
# 2      film  umbrella   bomb        prayer  flower   highway  satellite
# 3     movie  umbrella   bomb       shelter  flower   roadway  satellite
# 4  filmroll  umbrella   bomb          pray  flower      road       dish
# 5      film  umbrella   bomb  confessional  flower  roadsign   transmit
# 6     movie  umbrella   bomb          pray  flower      race  satellite
# 7     movie  umbrella   bomb          pray    rose   highway  satellite
# 8      film  umbrella   bomb       shelter  flower   freeway    antenna
# 9      roll  umbrella  light        symbol  flower      road     symbol
#
#       Feedback
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4  NO comments
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9         GOOD
#              Timestamp       Worker ID          👨‍💼     🛋️         🥴  \
# 0  02/12/2020 12:07:24   AFIK3VBMMX6G6     business   home    sickly
# 1  02/12/2020 12:07:37  A1CY01G7686ORZ     employee  couch  confused
# 2  02/12/2020 12:07:38  A1SFBJ5WW2OZTI   accountant  chair  confused
# 3  02/12/2020 12:09:44  A3AJ1VD5N8CSZV          man   sofa    smiley
# 4  02/12/2020 12:18:30  A38KXX5KH4BH9E          man   sofa       sad
# 5  02/12/2020 12:18:55  A3APAUBM8ARUP2          man  soffa       sad
# 6  02/12/2020 12:22:39   AUVPGHFV5MVKX          man   soba  uglyface
# 7  02/12/2020 12:32:49  A1XHK92L7Q7VEU  businessman   sofa     woozy
# 8  02/12/2020 12:32:56  A3T3H3RWDSX5P2       smiley  chair   feeling
# 9  02/12/2020 12:45:00  A3Q348SS5WGCV4       smiley  chair       sad
#
#           🖲️              🤤     ⭐           🥘         💊       🔨  \
# 0  spaceship       drooling  star        soup      pill  hammer
# 1      robot         hungry  star      dinner  medicine  hammer
# 2     button        content  star        soup     pills  hammer
# 3      light         smiley  star         pan    tablet  hammer
# 4       horn  facewithjollu  star         pan    tablet  hammer
# 5   lipstick   facewithjewl  star         pan   taplete   hamer
# 6     bottle   droolingface  star  pancooking    tablet  himmer
# 7     button       drooling  star        stew      pill  hammer
# 8     bottle       overflow  star     cooking    tablet  hammer
# 9     bottle         smiley  star     cooking    tablet  hammer
#
#                 😮           📟   Feedback
# 0        suprised      device        NaN
# 1       surprised       pager        NaN
# 2             wow       pager        NaN
# 3          smiley  calculator  excellent
# 4  speechlessface      laptop       GOOD
# 5  speachlessface      laptop       good
# 6  speachlessface       radio       good
# 7        surprise       pager        NaN
# 8          exited      tablet       none
# 9         excited      tablet         no
#               Timestamp       Worker ID            🥿          😔         🔽  \
# 0   02/12/2020 12:06:03  A3VG22WR5I4UG2         shoe  depressed  downvote
# 1   02/12/2020 12:09:30  A1CY01G7686ORZ         shoe        sad      down
# 2   02/12/2020 12:09:40  A18LAR2IV3FHF9         shoe        sad      down
# 3   02/12/2020 12:11:39   AFIK3VBMMX6G6         shoe        sad      down
# 4   02/12/2020 12:16:59   ACY3ZOOZMVS7Y         shoe        sad      down
# 5   02/12/2020 12:21:10  A1XHK92L7Q7VEU         shoe        sad      down
# 6   02/12/2020 12:21:48  A26WEZPGMW0HFH         show        sad      play
# 7   02/12/2020 12:21:54  A2EKBYYY72NRWU         shoe  depressed      down
# 8   02/12/2020 12:24:59   AUVPGHFV5MVKX  ladycutshow        sad  triangle
# 9   02/12/2020 12:25:16   AS4NIEQJWCG3M         shoe        sad  vertical
# 10  02/12/2020 12:43:13  A10WK0J5QZKZ40        shoes        sad      icon
#
#          👩       📹        ☀️           🍤               🚥       🎻        ⌨️  \
# 0    happy  camera       sun     seafood    trafficlight  guitar  keyboard
# 1     girl   video       sun      shrimp         traffic  violin  keyboard
# 2   female   video  sunshine       prawn         traffic  guitar  keyboard
# 3    woman  camera     sunny      shrimp          signal   cello  keyboard
# 4    happy  record  sunshine  stretching       stoplight  violin  keyboard
# 5    woman  camera       sun      shrimp       stoplight  violin  keyboard
# 6     girl   video       sun       snail     traficlight  guitar  keyboard
# 7     lady   video     sunny      shrimp          signal  fiddle  keyboard
# 8     girl  camera       sun      harron  trafficesignal  guitar  keyboard
# 9    woman  camera       sun      shrimp         traffic  violin  keyboard
# 10    girl  floder       sun       snake          single  violin  keyboard
#
#          🧙 Feedback
# 0   wizard      NaN
# 1   wizard      NaN
# 2      old      NaN
# 3   wizard      NaN
# 4   wizard      NaN
# 5   wizard      NaN
# 6    witch     none
# 7   wizard      NaN
# 8    joker     good
# 9   wizard      NaN
# 10  jocker   thanks

# %%
df0 = pd.read_csv("../data/processed/auto_mturk/forms_log_results/demographicrun5/0.csv")

# %%
df0
# Out:
#               Timestamp       Worker ID  Age  Gender Mothertongue        🔈  \
# 0   09/12/2020 12:05:54   AVXEDARJC5HLU   46    Male      english  speaker
# 1   09/12/2020 12:08:06  A2U5EPFZXHW519   50    Male      english     loud
# 2   09/12/2020 12:10:40   AGILQEFEPEK7N   30    Male      english    sound
# 3   09/12/2020 12:16:39   AQJRTW6LJR9LW   32    Male      english    sound
# 4   09/12/2020 12:19:04  A36QXX9UMJ7Y0R   33  Female      english  speaker
# 5   09/12/2020 12:19:26  A2IUUSQGQDEYID   34  Female      english  speaker
# 6   09/12/2020 12:23:46  A3W341JMZSKATX   47    Male      english  speaker
# 7   09/12/2020 12:25:07  A2CK0OXMPOR9LE   30    Male      english  speaker
# 8   09/12/2020 12:29:33   AIHUIAQ4922K3   31    Male      english  speaker
# 9   09/12/2020 12:36:40  A2D2JX8R0QU9G4   33  Female      english  speaker
# 10  09/12/2020 12:42:22   A8E3Z8XA32R90   25    Male      english    sound
#
#                 🥜         😆          📭         🎞️         ☂️       💣        🛐  \
# 0          peanut  laughing       mail      movie       rain    bomb   church
# 1          hungry   disgust       mail     cinema       rain    bomb     home
# 2             nut     laugh    mailbox       film   umbrella    bomb    kneel
# 3          peanut     laugh       mail     cinema   umbrella    bomb   church
# 4             nut     laugh  letterbox       film   umbrella    bomb  praying
# 5          peanut  laughing    mailbox       film       rain    bomb     pray
# 6   redbloodcells  laughter   substage      video   umbrella  ballon  praying
# 7          peanut  laughing    mailbox       film   umbrella    bomb   temple
# 8       groundnut   lauging    postbox  videotape  umburella    bomb   prayer
# 9          peanut     laugh    mailbox       flim   umbrella    bomb  worship
# 10         peanut     laugh       post      video   umbrella    bomb     pray
#
#          🌸       🛣️          📡  Feedback
# 0   flower  highway  satellite       NaN
# 1   flower     race     signal  its good
# 2   flower     trip  satellite       NaN
# 3   flower  highway  satellite       NaN
# 4   flowet     road    antenna       NaN
# 5   flower     road       loud    Thanks
# 6   flower  pathway       wifi  nice hit
# 7   flower  highway  satellite       NaN
# 8   flower  highway  satellite       NaN
# 9   flower  highway    antenna   nothing
# 10  flower  highway   satelite       NaN

# %%
df0 = pd.read_csv("../data/processed/auto_mturk/forms_log_results/run2/0.csv")
rej0 = ['A98G6J8I3V1GU']
df0[df0['Worker ID'].isin(rej0)]
# Out:
#              Timestamp      Worker ID      🏨     🟡       💎       🥖     🤾  \
# 4  01/12/2020 15:29:17  A98G6J8I3V1GU  house  moon  dimond  burger  play
#
#          ☂️      ✉️      🕧     🌴      🌷     👨‍🚀        🎃 Feedback
# 4  umberlaw  letter  watch  tree  lotus  player  pumbkin     nice

# %%
df1 = pd.read_csv("../data/processed/auto_mturk/forms_log_results/run2/1.csv")
rej1 = ['A12OZ7P7Z41SJI','A1J7VD5KF0A442','A34YRW76R9JICL','A2BZY06YRWGEDL','A1G5N2J0IMPJE8','A18LAR2IV3FHF9']
df1[df1['Worker ID'].isin(rej1)]
# Out:
#              Timestamp       Worker ID    👨‍🦲        🚶          🦪     🖊️  \
# 0  01/12/2020 15:26:26  A12OZ7P7Z41SJI  happy     walk       food  write
# 2  01/12/2020 15:27:29  A1J7VD5KF0A442   baby     walk        egg    pen
# 3  01/12/2020 15:36:12  A34YRW76R9JICL  joker     walk     omlete    pen
# 4  01/12/2020 15:41:55  A2BZY06YRWGEDL  happy  walking    golfing    pen
# 5  01/12/2020 15:56:13  A1G5N2J0IMPJE8  happy  walking    vetical    pen
# 9  01/12/2020 16:12:03  A18LAR2IV3FHF9   look     walk  omellette    pen
#
#        🐖      ⭐         🔠       😿        🥬       🍑            🎉         ☯️  \
# 0  money  aplus    simple     sad    salad   fruit        party   serenity
# 2    pig   star   letters  crying     leaf   fruit  celebration    reverse
# 3    pig   star  alphabet    fear     leaf   fruit        crisp     kungfu
# 4    pig   star      abcs     sad  lettuce   apple        party        yun
# 5    pig   star   letters     sad     leaf   apple       wishes        dot
# 9   pork   star   letters     cry     leaf  tomato     congrats  capricorn
#
#        Feedback
# 0           NaN
# 2          nice
# 3           yes
# 4           NaN
# 5          nice
# 9  Fascinating.

# %%
df2 = pd.read_csv("../data/processed/auto_mturk/forms_log_results/run2/2.csv")
rej2 = ["A1GNF163UX4A9D","A23L1W6O2ZROOP","A3TPW4JUUJDUFI","AHAD76MW0OBP","A1G5N2J0IMPJE8","A3LXERMGSXIFXC","A3AJ1VD5N8CSZV","A2D2JX8R0QU9G4","AP05055ECEO89"]
df2[df2['Worker ID'].isin(rej2)]
# Out:
#              Timestamp       Worker ID      👚       🦙          ⚡           🎓  \
# 0  01/12/2020 15:21:20  A1GNF163UX4A9D  shirt     dog      power         hat
# 1  01/12/2020 15:35:16  A23L1W6O2ZROOP  cloth   horse   charging  graduation
# 2  01/12/2020 15:37:16  A3TPW4JUUJDUFI  shirt    deer      spark    graduate
# 3  01/12/2020 15:43:38    AHAD76MW0OBP  dress  animal       idea  literation
# 4  01/12/2020 15:45:58  A1G5N2J0IMPJE8  shirt    duck      prise   education
# 5  01/12/2020 15:50:38  A3LXERMGSXIFXC  shirt  animal       fast    graduate
# 6  01/12/2020 15:51:38  A3AJ1VD5N8CSZV  shart     dog      power         cap
# 8  01/12/2020 16:05:32  A2D2JX8R0QU9G4  shirt    dear  lightning         hat
# 9  01/12/2020 16:21:53   AP05055ECEO89  shirt    deer     symbol         cap
#
#          😼      ☀️          〰️        🥓           🔐     🦆           💯  \
# 0      cat     sun        wave  rainbow        lock  duck        good
# 1     meow  bright  wavelength  rainbow    security  duck       score
# 2      cat     sun        wave     wave         key  duck  percentage
# 3  revenge   sunny        wave    sweet        lock  duck     perfect
# 4   animal     sun       water  rainbow         key  duck        mark
# 5    angry   light      dimple    waves  lockandkey  duck      centum
# 6      cat     sun        bend     beef        lock  duck      number
# 8      cat     sun        wave  chewing        lock  duck     century
# 9    angry     sun     drawing    river        lock  duck      number
#
#           📮     Feedback
# 0      post         good
# 1      mail  nice survey
# 2     watch          NaN
# 3      mail          NaN
# 4      mail         nice
# 5  redlight         good
# 6   message     interest
# 8      mail      Nothing
# 9    signal         good

# %%
df0 = pd.read_csv("../data/processed/auto_mturk/forms_results/0.csv")
df1 = pd.read_csv("../data/processed/auto_mturk/forms_results/1.csv")

# %%
def get_honey_wrong(form_df,honeypots,dist_lshtein=2):
    form_df = form_df.set_index('Worker ID').copy()
    honey_columns = [em for em in form_df.columns if em in honeypots.keys()]
    form_df = form_df[honey_columns]
    assert(form_df.shape[1] > 0)
    for em in honey_columns:
        corr_words = honeypots[em]
        form_df[em] = form_df[em].apply(lambda word: min([Levenshtein.distance(word,corr_word) for corr_word in corr_words]) > dist_lshtein)
    return form_df

# %%
set(df0['Worker ID'].unique()).intersection(set(df1['Worker ID'].unique()))
# Out:
# {'A154DNFWSBSS8D',
#  'A1OWHL50LZGO1G',
#  'A2D2JX8R0QU9G4',
#  'A30UE6DWFNUCWX',
#  'A3211VPCMNHVL5',
#  'A3VG22WR5I4UG2'}

# %%
detect_honey_frauders(df1,HONEYPOTS)
# Out:
# {'A154DNFWSBSS8D',
#  'A19NFE5IPAVU0O',
#  'A1OWHL50LZGO1G',
#  'A2D2JX8R0QU9G4',
#  'A2XYJ3QI1T5T7N',
#  'A30UE6DWFNUCWX',
#  'A3211VPCMNHVL5',
#  'A3AJ1VD5N8CSZV',
#  'A3VG22WR5I4UG2'}
